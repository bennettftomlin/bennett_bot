# %%
import pandas as pd

# %%
tweets = pd.read_json('tweet.js')

# %%
tweets
# Out:
#                created_at display_text_range  \
# 0     2019-11-14 00:17:44           [0, 118]
# 1     2019-11-14 00:16:57            [0, 90]
# 2     2019-11-14 00:16:25            [0, 86]
# 3     2019-11-14 00:09:58           [0, 114]
# 4     2019-11-14 00:08:33           [0, 147]
# 5     2019-11-14 00:05:39            [0, 35]
# 6     2019-11-14 00:05:34            [0, 63]
# 7     2019-11-13 23:48:17            [0, 84]
# 8     2019-11-13 23:10:56            [0, 53]
# 9     2019-11-13 22:49:57            [0, 58]
# 10    2019-11-13 22:32:12            [0, 52]
# 11    2019-11-13 22:28:20            [0, 41]
# 12    2019-11-13 18:24:38            [0, 70]
# 13    2019-11-13 17:12:50            [0, 64]
# 14    2019-11-13 16:50:24            [0, 20]
# 15    2019-11-13 16:37:24            [0, 44]
# 16    2019-11-13 15:51:22           [0, 183]
# 17    2019-11-13 15:27:21            [0, 30]
# 18    2019-11-13 15:04:40           [0, 122]
# 19    2019-11-13 15:01:18           [0, 150]
# ...

# %%
tweets.columns
# Out:
# Index(['created_at', 'display_text_range', 'entities', 'extended_entities',
#        'favorite_count', 'favorited', 'full_text', 'id', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'lang', 'possibly_sensitive',
#        'retweet_count', 'retweeted', 'source', 'truncated',
#        'withheld_copyright', 'withheld_in_countries'],
#       dtype='object')

# %%
export = tweets[['full_text']]
export
# Out:
#                                                full_text
# 0      @IamNomad @CasPiancey The assertion is accurat...
# 1      @IamNomad @CasPiancey Money was transferred in...
# 2      @IamNomad @CasPiancey This was before the loan...
# 3      @IamNomad @CasPiancey iFinex shared posted by ...
# 4      @IamNomad @CasPiancey That's what I said. Teth...
# 5                    @IamNomad @CasPiancey Doc 1 that is
# 6      @IamNomad @CasPiancey This is not backwards. C...
# 7      @DnDcapital @Bitfinexed I am not. Dude has bee...
# 8      New version of this paragraph https://t.co/k26...
# 9      @abeautifultroll It's a book I am writing with...
# 10     #totallynormalbusinessthings https://t.co/h37k...
# 11             #fud #1usdt1horse https://t.co/KUVZyEYeQi
# 12     @Rebelbanker Techniques to help identify fraud...
# 13     @twuench lol I need to learn how to do it not ...
# 14                                  @PlugInFUD Thank you
# ...

# %%
export = export[~export["full_text"].str.contains('RT')]
export.reset_index(drop=True)
export
# Out:
#        index                                          full_text
# 0          0  @IamNomad @CasPiancey The assertion is accurat...
# 1          1  @IamNomad @CasPiancey Money was transferred in...
# 2          2  @IamNomad @CasPiancey This was before the loan...
# 3          3  @IamNomad @CasPiancey iFinex shared posted by ...
# 4          4  @IamNomad @CasPiancey That's what I said. Teth...
# 5          5                @IamNomad @CasPiancey Doc 1 that is
# 6          6  @IamNomad @CasPiancey This is not backwards. C...
# 7          7  @DnDcapital @Bitfinexed I am not. Dude has bee...
# 8          8  New version of this paragraph https://t.co/k26...
# 9          9  @abeautifultroll It's a book I am writing with...
# 10        10  #totallynormalbusinessthings https://t.co/h37k...
# 11        11          #fud #1usdt1horse https://t.co/KUVZyEYeQi
# 12        12  @Rebelbanker Techniques to help identify fraud...
# 13        13  @twuench lol I need to learn how to do it not ...
# ...

# %%
type(export)

# %%
export.to_csv('tweets.csv')
