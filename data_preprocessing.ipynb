# %%
import pandas as pd

# %%
tweets = pd.read_json('tweet.js')

# %%
tweets.head()
# Out:
#            created_at display_text_range  \
# 0 2019-11-14 00:17:44           [0, 118]
# 1 2019-11-14 00:16:57            [0, 90]
# 2 2019-11-14 00:16:25            [0, 86]
# 3 2019-11-14 00:09:58           [0, 114]
# 4 2019-11-14 00:08:33           [0, 147]
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
#
#    favorite_count  favorited  \
# 0               0      False
# 1               0      False
# 2               0      False
# 3               0      False
# 4               0      False
#
#                                            full_text                   id  \
# ...

# %%
tweets.columns
# Out:
# Index(['created_at', 'display_text_range', 'entities', 'extended_entities',
#        'favorite_count', 'favorited', 'full_text', 'id', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'lang', 'possibly_sensitive',
#        'retweet_count', 'retweeted', 'source', 'truncated',
#        'withheld_copyright', 'withheld_in_countries'],
#       dtype='object')

# %%
export = tweets[tweets['retweeted'] == False]['full_text']
export
# Out:
# 0        @IamNomad @CasPiancey The assertion is accurat...
# 1        @IamNomad @CasPiancey Money was transferred in...
# 2        @IamNomad @CasPiancey This was before the loan...
# 3        @IamNomad @CasPiancey iFinex shared posted by ...
# 4        @IamNomad @CasPiancey That's what I said. Teth...
# 5                      @IamNomad @CasPiancey Doc 1 that is
# 6        @IamNomad @CasPiancey This is not backwards. C...
# 7        @DnDcapital @Bitfinexed I am not. Dude has bee...
# 8        New version of this paragraph https://t.co/k26...
# 9        @abeautifultroll It's a book I am writing with...
# 10       #totallynormalbusinessthings https://t.co/h37k...
# 11               #fud #1usdt1horse https://t.co/KUVZyEYeQi
# 12       @Rebelbanker Techniques to help identify fraud...
# 13       @twuench lol I need to learn how to do it not ...
# 14                                    @PlugInFUD Thank you
# 15            What’s the best book on forensic accounting?
# ...

# %%
type(export)
# Out:
# pandas.core.series.Series

# %%
export.to_csv('tweets.csv')
# Out:
# /Users/Bennett1/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
